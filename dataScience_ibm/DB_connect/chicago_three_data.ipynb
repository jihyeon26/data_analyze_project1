# %%
import prettytable

prettytable.DEFAULT = 'DEFAULT'

# %%
import csv, pandas as pd, sqlite3

con = sqlite3.connect("FinalDB.db")
cur=con.cursor()

# %%
# %load_ext sql
# %sql sqlite:///FinalDB.db

# %%
df1 = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01")
df2 = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01")
df3 = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01")

df1.to_sql("census_data", con, if_exists='replace', index=False)
df2.to_sql("public_schools", con, if_exists='replace', index=False)
df3.to_sql("crime_data", con, if_exists='replace', index=False)
# Out:
# 533

# %%
# %sql SELECT name FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('census_data',), ('public_schools',), ('crime_data',)]

# %%
# %sql SELECT * FROM PRAGMA_TABLE_INFO('census_data');
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(0, 'COMMUNITY_AREA_NUMBER', 'REAL', 0, None, 0),
#  (1, 'COMMUNITY_AREA_NAME', 'TEXT', 0, None, 0),
#  (2, 'PERCENT_OF_HOUSING_CROWDED', 'REAL', 0, None, 0),
#  (3, 'PERCENT_HOUSEHOLDS_BELOW_POVERTY', 'REAL', 0, None, 0),
#  (4, 'PERCENT_AGED_16__UNEMPLOYED', 'REAL', 0, None, 0),
#  (5, 'PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', 'REAL', 0, None, 0),
#  (6, 'PERCENT_AGED_UNDER_18_OR_OVER_64', 'REAL', 0, None, 0),
#  (7, 'PER_CAPITA_INCOME', 'INTEGER', 0, None, 0),
#  (8, 'HARDSHIP_INDEX', 'REAL', 0, None, 0)]

# %%
# %sql SELECT * FROM PRAGMA_TABLE_INFO('crime_data')
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(0, 'ID', 'INTEGER', 0, None, 0),
#  (1, 'CASE_NUMBER', 'TEXT', 0, None, 0),
#  (2, 'DATE', 'TEXT', 0, None, 0),
#  (3, 'BLOCK', 'TEXT', 0, None, 0),
#  (4, 'IUCR', 'TEXT', 0, None, 0),
#  (5, 'PRIMARY_TYPE', 'TEXT', 0, None, 0),
#  (6, 'DESCRIPTION', 'TEXT', 0, None, 0),
#  (7, 'LOCATION_DESCRIPTION', 'TEXT', 0, None, 0),
#  (8, 'ARREST', 'INTEGER', 0, None, 0),
#  (9, 'DOMESTIC', 'INTEGER', 0, None, 0),
#  (10, 'BEAT', 'INTEGER', 0, None, 0),
#  (11, 'DISTRICT', 'INTEGER', 0, None, 0),
#  (12, 'WARD', 'REAL', 0, None, 0),
#  (13, 'COMMUNITY_AREA_NUMBER', 'REAL', 0, None, 0),
#  (14, 'FBICODE', 'TEXT', 0, None, 0),
#  (15, 'X_COORDINATE', 'REAL', 0, None, 0),
#  (16, 'Y_COORDINATE', 'REAL', 0, None, 0),
#  (17, 'YEAR', 'INTEGER', 0, None, 0),
#  (18, 'LATITUDE', 'REAL', 0, None, 0),
#  (19, 'LONGITUDE', 'REAL', 0, None, 0),
#  (20, 'LOCATION', 'TEXT', 0, None, 0)]

# %%
# %%sql
# SELECT "Elementary, Middle, or High School", AVG(SAFETY_SCORE)
# FROM public_schools
# GROUP BY "Elementary, Middle, or High School"
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('ES', 49.52038369304557), ('HS', 49.62352941176471), ('MS', 48.0)]

# %%
# %sql SELECT COUNT(CASE_NUMBER),COMMUNITY_AREA_NUMBER,   FROM crime_data GROUP BY COMMUNITY_AREA_NUMBER ORDER BY COUNT(CASE_NUMBER) DESC;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(43, 25.0),
#  (43, None),
#  (22, 23.0),
#  (21, 68.0),
#  (16, 29.0),
#  (16, 28.0),
#  (15, 8.0),
#  (14, 71.0),
#  (13, 24.0),
#  (12, 67.0),
#  (12, 66.0),
#  (11, 69.0),
#  (11, 49.0),
#  (11, 6.0),
#  (10, 61.0),
#  (10, 58.0),
#  (10, 26.0),
#  (9, 46.0),
#  (9, 43.0),
#  (9, 31.0),
#  (9, 22.0),
#  (8, 70.0),
#  (8, 44.0),
#  (8, 42.0),
#  (8, 38.0),
#  (8, 30.0),
#  (8, 27.0),
#  (8, 19.0),
#  (8, 16.0),
#  (7, 63.0),
#  (7, 32.0),
#  (7, 2.0),
#  (6, 53.0),
#  (6, 21.0),
#  (6, 1.0),
#  (5, 48.0),
#  (5, 35.0),
#  (5, 15.0),
#  (5, 14.0),
#  (5, 7.0),
#  (4, 76.0),
#  (4, 72.0),
#  (4, 62.0),
#  (4, 51.0),
#  (4, 45.0),
#  (4, 39.0),
#  (4, 5.0),
#  (4, 3.0),
#  (3, 73.0),
#  (3, 65.0),
#  (3, 50.0),
#  (3, 20.0),
#  (3, 17.0),
#  (3, 10.0),
#  (3, 4.0),
#  (2, 77.0),
#  (2, 64.0),
#  (2, 59.0),
#  (2, 56.0),
#  (2, 54.0),
#  (2, 52.0),
#  (2, 41.0),
#  (2, 37.0),
#  (2, 18.0),
#  (2, 11.0),
#  (1, 75.0),
#  (1, 60.0),
#  (1, 55.0),
# ...

# %%
# %sql SELECT COUNT(CR.CASE_NUMBER), CR.COMMUNITY_AREA_NUMBER, CE.COMMUNITY_AREA_NAME FROM crime_data CR, census_data CE WHERE CE.COMMUNITY_AREA_NUMBER=CR.COMMUNITY_AREA_NUMBER GROUP BY CR.COMMUNITY_AREA_NUMBER ORDER BY COUNT(CR.CASE_NUMBER) DESC;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(43, 25.0, 'Austin'),
#  (22, 23.0, 'Humboldt park'),
#  (21, 68.0, 'Englewood'),
#  (16, 29.0, 'North Lawndale'),
#  (16, 28.0, 'Near West Side'),
#  (15, 8.0, 'Near North Side'),
#  (14, 71.0, 'Auburn Gresham'),
#  (13, 24.0, 'West Town'),
#  (12, 67.0, 'West Englewood'),
#  (12, 66.0, 'Chicago Lawn'),
#  (11, 69.0, 'Greater Grand Crossing'),
#  (11, 49.0, 'Roseland'),
#  (11, 6.0, 'Lake View'),
#  (10, 61.0, 'New City'),
#  (10, 58.0, 'Brighton Park'),
#  (10, 26.0, 'West Garfield Park'),
#  (9, 46.0, 'South Chicago'),
#  (9, 43.0, 'South Shore'),
#  (9, 31.0, 'Lower West Side'),
#  (9, 22.0, 'Logan Square'),
#  (8, 70.0, 'Ashburn'),
#  (8, 44.0, 'Chatham'),
#  (8, 42.0, 'Woodlawn'),
#  (8, 38.0, 'Grand Boulevard'),
#  (8, 30.0, 'South Lawndale'),
#  (8, 27.0, 'East Garfield Park'),
#  (8, 19.0, 'Belmont Cragin'),
#  (8, 16.0, 'Irving Park'),
#  (7, 63.0, 'Gage Park'),
#  (7, 32.0, 'Loop'),
#  (7, 2.0, 'West Ridge'),
# ...
